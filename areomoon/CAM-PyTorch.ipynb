# %% [markdown]
# # CAM-PyTorch

# %% [markdown]
# We will implement CAM by PyTorch.

# %%
import os 
os.chdir('src/')

# %% [markdown]
# ### Import Labraries

# %%
from models import SE_ResNext101_32x4d
from CAM import CAM
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = SE_ResNext101_32x4d(pretrained=False, n_class=3)
model.load_state_dict(torch.load('../se_resnext101_32x4d_fold_4.bin',map_location=lambda storage, loc: storage))
model.eval()

cam = CAM(model)

# %% [markdown]
# # Actual C,Pred  B

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00082.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00119.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00427.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00760.jpg', top=3)

# %% [markdown]
# # Actual A,Pred  B

# %% [markdown]
# Brightness, detect hands?

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00187.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/00570.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/01246.jpg', top=3)

# %%
cam.plot_image_heatmap('../C1-P1_Train_Dev_fixed/C1-P1_Dev/01324.jpg', top=3)
