# %% [markdown]
# # CAM-PyTorch

# %% [markdown]
# We will implement CAM by PyTorch.

# %%
import os 
os.chdir('src/')

# %% [markdown]
# ### Import Labraries

# %%
from models import VGG16
from CAM import CAM
import torch
import mat

# %%
model = VGG16(pretrained=False, n_class=3)
model.load_state_dict(torch.load('../vgg16_fold_4.bin',map_location=lambda storage, loc: storage))
model.eval()

cam = CAM(model)
cam.plot_image_heatmap('../AIMango_sample/sample_image/D-Plant2_0610_306.jpg', top=3)
